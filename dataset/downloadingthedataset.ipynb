# %% [markdown]
# Git clone in the dataset repo

# %% [markdown]
# git clone https://huggingface.co/datasets/MichalMlodawski/closed-open-eyes

# %% [markdown]
# download lfs

# %% [markdown]
# brew install git-lfs
# git lfs install

# %% [markdown]
# Pull in the repo

# %% [markdown]
# git lfs pull
